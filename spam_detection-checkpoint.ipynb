# %%
# !pip install pandas

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-82a38e2409a7> in <module>
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 from matplotlib import rcParams
#       4 from matplotlib.cm import rainbow
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
a=pd.read_csv(r"E:\PROJECTS\Spam_Detection_in_Twitter\input\Spam.csv")
b=pd.read_csv("E:\PROJECTS\Spam_Detection_in_Twitter\input\Ham.csv")

spam=a.filter(items=['message'])
ham=b.filter(items=['message'])

# %%
print(spam)
spam.to_csv('E:/PROJECTS/Spam_Detection_in_Twitter/spam.csv',index=False)
# Out:
#                                                message
# 0    Free entry in 2 a wkly comp to win FA Cup fina...
# 1    FreeMsg Hey there darling it's been 3 week's n...
# 2    WINNER!! As a valued network customer you have...
# 3    Had your mobile 11 months or more? U R entitle...
# 4    SIX chances to win CASH! From 100 to 20,000 po...
# ..                                                 ...
# 742  Want explicit SEX in 30 secs? Ring 02073162414...
# 743  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...
# 744  Had your contract mobile 11 Mnths? Latest Moto...
# 745  REMINDER FROM O2: To get 2.50 pounds free call...
# 746  This is the 2nd time we have tried 2 contact u...
#
# [747 rows x 1 columns]

# %%
print(ham)
ham.to_csv('E:/PROJECTS/Spam_Detection_in_Twitter/ham.csv',index=False)
# Out:
#                                                 message
# 0     Go until jurong point, crazy.. Available only ...
# 1                         Ok lar... Joking wif u oni...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     Even my brother is not like to speak with me. ...
# ...                                                 ...
# 4820                                       Huh y lei...
# 4821              Will Ì_ b going to esplanade fr home?
# 4822  Pity, * was in mood for that. So...any other s...
# 4823  The guy did some bitching but I acted like i'd...
# 4824                         Rofl. Its true to its name
#
# [4825 rows x 1 columns]

# %%
dataset = pd.concat([spam,ham])
print(dataset)
# Out:
#                                                 message
# 0     Free entry in 2 a wkly comp to win FA Cup fina...
# 1     FreeMsg Hey there darling it's been 3 week's n...
# 2     WINNER!! As a valued network customer you have...
# 3     Had your mobile 11 months or more? U R entitle...
# 4     SIX chances to win CASH! From 100 to 20,000 po...
# ...                                                 ...
# 4820                                       Huh y lei...
# 4821              Will Ì_ b going to esplanade fr home?
# 4822  Pity, * was in mood for that. So...any other s...
# 4823  The guy did some bitching but I acted like i'd...
# 4824                         Rofl. Its true to its name
#
# [5572 rows x 1 columns]

# %%
import nltk
import random
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize

# %%
class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf

# %%
Spam = open("E:/PROJECTS/Spam_Detection_in_Twitter/spam.csv", "r",encoding='utf-8').read()
Ham = open("E:/PROJECTS/Spam_Detection_in_Twitter/ham.csv", "r",encoding='utf-8').read()

# %%
all_words = []
documents = []
allowed_word_types = ["J"]

for p in Spam.split('\n'):
    documents.append((p, "Spam"))
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())
#print(all_words) 
#print(documents)
classify1=pd.DataFrame(documents)
classify1.to_csv('E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/Spam_new.csv',header=None)

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
df = pd.read_csv("E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/Spam_new.csv") 
comment_words= ''
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df['message']: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
all_words = []
documents = []
allowed_word_types = ["J"]

for p in Ham.split('\n'):
    documents.append((p, "Ham"))
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())
#print(all_words) 
#print(documents)
classify2=pd.DataFrame(documents)
classify2.to_csv("E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/Ham_new.csv",header=None)

# %%
df = pd.read_csv("E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/Ham_new.csv") 
comment_words= ''
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df['message']: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
preprocess_all = pd.concat([classify1,classify2])
#print(preprocess_all)
preprocess_all.to_csv('E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/preprocess_all.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC, NuSVC

dataset2=pd.read_csv('E:/PROJECTS/Spam_Detection_in_Twitter/preprocess/preprocess_all.csv')
dataset2['label'] = dataset2['1'].map({'Ham': 0,'Spam': 1})
y = dataset2['1']
X = dataset2['0']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
rcParams['figure.figsize'] = 10,6
plt.bar(dataset2['1'].unique(), dataset2['1'].value_counts(), color = ['red', 'green'])
#plt.xticks([0,1])
#plt.xlabel('students activities')
plt.ylabel('Count')
plt.title('Classification')
# Out:
# Text(0.5, 1.0, 'Classification')
